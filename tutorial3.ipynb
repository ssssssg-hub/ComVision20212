# %%
d = {'user':'bozo', 'pswd':1234}

# %%
d['user']
# Out:
# 'bozo'

# %%
d['pswd']
# Out:
# 1234

# %%
d['bozo']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/cy/683ybj7j10v6jd1s9062_f780000gn/T/ipykernel_92198/657352856.py in <module>
# ----> 1 d['bozo']
#
# KeyError: 'bozo'

# %%
d = {'user':'bozo', 'pswd':1234}

# %%
d['user'] = 'clown'

# %%
d
# Out:
# {'user': 'clown', 'pswd': 1234}

# %%
d['id'] = 45

# %%
d
# Out:
# {'user': 'clown', 'pswd': 1234, 'id': 45}

# %%
d = {'user':'bozo', 'p':1234, 'i':34}

# %%
del d['user']

# %%
d
# Out:
# {'p': 1234, 'i': 34}

# %%
d.clear()

# %%
d
# Out:
# {}

# %%
a = [1, 2]

# %%
del a[1]

# %%
a
# Out:
# [1]

# %%
d = {'user':'bozo', 'p':1234, 'i':34}

# %%
d.keys()
# Out:
# dict_keys(['user', 'p', 'i'])

# %%
d.values()
# Out:
# dict_values(['bozo', 1234, 34])

# %%
d.items()
# Out:
# dict_items([('user', 'bozo'), ('p', 1234), ('i', 34)])
