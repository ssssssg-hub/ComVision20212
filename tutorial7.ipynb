# %%
li = [3, 6, 2, 7]

# %%
[elem * 2 for elem in li]
# Out:
# [6, 12, 4, 14]

# %%
li = [('a', 1), ('b', 2), ('c', 7)]

# %%
[n * 3 for (x, n) in li]
# Out:
# [3, 6, 21]

# %%
li = [3, 6, 2, 7, 1, 9]

# %%
[elem * 2 for elem in li if elem > 4]
# Out:
# [12, 14, 18]

# %%
li = [3, 2, 4, 1]

# %%
[elem * 2 for elem in [i + 1 for i in li]]
# Out:
# [8, 6, 10, 4]
