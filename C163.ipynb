# %%
import numpy as np
import cv2

# %%
cap = cv2.VideoCapture('monitoring_720p.mp4')
fgbg = cv2.createBackgroundSubtractorMOG()
#fgbg = cv2.bgsegm.createBackgroundSubtractorMOG()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/cy/683ybj7j10v6jd1s9062_f780000gn/T/ipykernel_9071/1394608529.py in <module>
#       1 cap = cv2.VideoCapture('monitoring_720p.mp4')
# ----> 2 fgbg = cv2.createBackgroundSubtractorMOG()
#       3 #fgbg = cv2.bgsegm.createBackgroundSubtractorMOG()
#
# AttributeError: module 'cv2.cv2' has no attribute 'createBackgroundSubtractorMOG'

# %%
while(1):
    ret, frame = cap.read()
    fgmask = fgbg.apply(frame)
    cv2.imshow('frame',fgmask)
    k = cv2.waitKey(30) & 0xff
    if k == 27:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/cy/683ybj7j10v6jd1s9062_f780000gn/T/ipykernel_9071/3480481516.py in <module>
#       1 while(1):
#       2     ret, frame = cap.read()
# ----> 3     fgmask = fgbg.apply(frame)
#       4     cv2.imshow('frame',fgmask)
#       5     k = cv2.waitKey(30) & 0xff
#
# NameError: name 'fgbg' is not defined

# %%
cap = cv2.VideoCapture('monitoring_720p.mp4')
fgbg = cv2.createBackgroundSubtractorMOG2(detectShadows=True)
#fgbg = cv2.bgsegm.createBackgroundSubtractorMOG2()

# %%
while(1):
    ret, frame = cap.read()
    fgmask = fgbg.apply(frame)
    cv2.imshow('frame',fgmask)
    k = cv2.waitKey(30) & 0xff
    if k == 27:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /var/folders/cy/683ybj7j10v6jd1s9062_f780000gn/T/ipykernel_9071/3480481516.py in <module>
#       2     ret, frame = cap.read()
#       3     fgmask = fgbg.apply(frame)
# ----> 4     cv2.imshow('frame',fgmask)
#       5     k = cv2.waitKey(30) & 0xff
#       6     if k == 27:
#
# error: OpenCV(4.5.3) /private/var/folders/24/8k48jl6d249_n_qfxwsl6xvm0000gn/T/pip-req-build-tetsazc6/opencv/modules/highgui/src/window.cpp:1006: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'imshow'

# %%
cap = cv2.VideoCapture('monitoring_720p.mp4')

# %%
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(3,3))
fgbg = cv2.createBackgroundSubtractorGMG()

# %%
while(1):
    ret, frame = cap.read()
    fgmask = fgbg.apply(frame)
    cv2.imshow('vframe',frame)
    cv2.imshow('frame',fgmask)
    k = cv2.waitKey(30) & 0xff
    if k == 27:
        break
cap.release()
cv2.destroyAllWindows()
