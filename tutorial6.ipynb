# %%
for someChar in 'Hello World':
    print(someChar)
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %%
for (x, y) in [(1, 1), (2, 2), (3, 3)]:
    print(x, y)
# Out:
# 1 1
# 2 2
# 3 3

# %%
for x in range(5):
    print(x)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for (i, item) in enumerate('Hello'):
    print(i, item)
# Out:
# 0 H
# 1 e
# 2 l
# 3 l
# 4 o
